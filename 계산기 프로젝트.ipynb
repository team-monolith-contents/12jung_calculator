# %% [markdown]
# ## **계산기 프로젝트**
#
# ![image.png](attachment:1f238da1-9fbb-4fc9-8df7-ae225f7f330a.png)
#
# > 지금까지 배운 내용을 이용해서 계산기를 만들어봅니다.
#
# > 할 수 있는 많은 종류의 연산을 해보세요.
#
# 1. 계산할 두 개의 변수를 선언하고 값 저장
# 2. 두 개의 변수를 연산해서 새로운 변수에 연산 결과 저장
# 3. 연산 결과 출력

# %%
# 1. 계산할 두 개의 변수를 선언하고 값 저장
num1 = 
num2 = 

# 2. 두 개의 변수 연산해서 새로운 변수에 연산 결과 저장
sum = 




# 3. 연산 결과 출력
print(sum)
# Out:
#   Cell In[1], line 2
#     num1 =
#            ^
# SyntaxError: invalid syntax
